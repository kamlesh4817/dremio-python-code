# %%
import requests

## Function to Retrieve PAT TOken from Dremio
def get_token(uri, payload):
    # Make the POST request
    response = requests.post(uri, json=payload)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        # Extract the token
        return data.get("token", "")

    else:
        print("Failed to get a valid response. Status code:", response.status_code)

## Username and Password for Dremio Account
username = "dremio"
password = "dremio123"

## Dremio REST API URL
uri = "http://automaster:9047/apiv2/login"

## Payload for Get Token Requests
payload = {
    "userName": username,
    "password": password
}

token = get_token(uri, payload)
print("Token:", token)
# Out:
# Token: fa45qpv9i7m7ec4qndfjsqq963
